# %%
from src.video_composition.video.static_background_image_component import StaticBackgroundImageComponent
from src.video_composition.composer import VideoComposition
from src.video_composition.video.text_component import TextComponent
from src.video_composition.video.timed_text_component import TimedTextComponent
from src.video_composition.video.pan_image_component import PanImageComponent
from src.video_composition.audio.audio_component import AudioComponent
from src.video_composition.audio.audio_file_component import AudioFileComponent
from src.video_composition.combo.componenet_container import ComponentContainer
from src.video_composition.combo.mp4_componenet import MP4Component

from src.video_composition.combo.tts_componenet import TTSComponenet

background_start_time = 2  # Start at 2 seconds into the video
background_duration = 10  # Last for 10 seconds
text_start_time = 4  # Start at 4 seconds into the video
text_duration = 5  # Last for 5 seconds

# HD phone resolution
# width = 1920
# height = 1080

width = 1024
height = 1024

fps = 30
font = 70
output_file = 'composition.mp4'
image = 'image.png'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       8 from src.video_composition.combo.componenet_container import ComponentContainer
#       9 from src.video_composition.combo.mp4_componenet import MP4Component
# ---> 11 from src.video_composition.combo.tts_componenet import TTSComponenet
#      13 background_start_time = 2  # Start at 2 seconds into the video
#      14 background_duration = 10  # Last for 10 seconds
#
# File ~/Desktop/Programming/PugTech/tts-video/src/video_composition/combo/tts_componenet.py:4
#       2 from src.video_composition.audio.audio_component import AudioComponent
#       3 from src.video_composition.video.timed_text_component import TimedTextComponent
# ----> 4 from src.tts import TextToSpeech
#       6 # Sound from TTS is kinda soft, so amplify it by default.
#       7 AMPLIFICATION = 4
#
# File ~/Desktop/Programming/PugTech/tts-video/src/tts.py:2
#       1 from collections import namedtuple
# ----> 2 from TTS.utils.synthesizer import Synthesizer
#       3 from IPython.display import Audio
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'TTS'

# %%
from src.video_composition.video.pan_image_component import PanImageComponent
from src.video_composition.composer import VideoComposition
from src.video_composition.video.text_component import TextComponent

background_start_time = 2  # Start at 2 seconds into the video
background_duration = 10  # Last for 10 seconds
text_start_time = 4  # Start at 4 seconds into the video
text_duration = 5  # Last for 5 seconds

# HD phone resolution
# width = 1920
# height = 1080

width = 540
height = 960

fps = 60
font = 70
output_file = 'composition.mp4'
image = 'image.png'

video_composition = VideoComposition(width=width, height=height, fps=fps)
video_composition.add_video_component(PanImageComponent(image, width=width, height=height, fps=fps, start_time=background_start_time, duration=background_duration))
video_composition.add_video_component(TextComponent(text="Hello", font=font, width=width, height=height, fps=fps, start_time=text_start_time, duration=text_duration))
video_composition.create_video(output_file=output_file)
# Out:
# Component: 120 - 720
# Duration: 10
# Component: 240 - 540
# Duration: 5

# %%
video_composition = VideoComposition(width=width, height=height, fps=fps)
video_composition.add_video_component(PanImageComponent(image, width=width, height=height, fps=fps, start_time=background_start_time, duration=background_duration))
video_composition.add_video_component(TextComponent(text="Hello", font=font, width=width, height=height, fps=fps, start_time=text_start_time, duration=text_duration))
video_composition.create_video(output_file=output_file)
# Out:
# Component: 60 - 360
# Duration: 10
# Component: 120 - 270
# Duration: 5

# %%
from IPython.display import Audio
import contextlib

# text = "Hello world. This is a test of, the text to speech system.  Here's a third sentence. And a fourth. How about a fifth?"
text = "Hello world."
output = None
with contextlib.redirect_stdout(None):
    from src.tts import TextToSpeech

    output = TextToSpeech.text_to_audio(text, speaker_name="p227", speed=.4)

Audio(output.audio, rate=22050)
# 5 or 10 seconds
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
output_file = "tts.mp4"
background_start_time = 1

wav = "bach.wav"

words = text.split()
duration = output.total_running_time_s
start = 2
timestamps = [time / 86 + start for time in output.word_timestamps]

video_composition = VideoComposition(width=width, height=height, fps=fps)
video_composition.add_video_component(StaticBackgroundImageComponent(image, width=width, height=height, fps=fps, start_time=background_start_time, duration=background_duration))
video_composition.add_video_component(TimedTextComponent(words, timestamps, width=width, height=height, fps=fps, start_time=start, duration=duration))
video_composition.add_audio_component(AudioFileComponent(wav, start_time=0))
video_composition.add_audio_component(AudioComponent(output.audio*5, start_time=start))
video_composition.create_video(output_file=output_file)
# Out:
# Component: 30 - 330
# Duration: 10
# Component: 60 - 143
# Duration: 2.787120181405896

# %%
output_file = "container-test.mp4"
ttc = TimedTextComponent(words, timestamps, start_time=1, duration=output.total_running_time_s, width=width, height=height, fps=fps)
ac = AudioComponent(output.audio * 4, start_time=1)
mc = AudioFileComponent(wav, start_time=1)

container = ComponentContainer()
container.add_component(ttc)
container.add_component(ac)
container.add_component(mc)

video_composition = VideoComposition(width=width, height=height, fps=fps)
video_composition.add_component(container)
video_composition.create_video(output_file)
# Out:
# Component: 30 - 113
# Duration: 2.787120181405896

# %%
video_composition = VideoComposition(width=1080, height=1920, fps=fps)
video_composition.add_component(TTSComponenet("Testing a component containing text and sound.  It should be easy to use.", fps=fps, color=(255, 0, 0)))
video_composition.add_component(TTSComponenet("You should be able to stagger sentences.", fps=fps, start=4, color=(0, 255, 0)))
video_composition.create_video(output_file)
# Out:
#  > Text splitted to sentences.
# ['Testing a component containing text and sound']
#  > Processing time: 0.7497780323028564
#  > Real-time factor: 0.21169593336762427
#  > Text splitted to sentences.
# ['It should be easy to use.']
#  > Processing time: 0.4594271183013916
#  > Real-time factor: 0.203912398521451
# Component: 0 - 173
# Duration: 5.794829931972789
#  > Text splitted to sentences.
# ['You should be able to stagger sentences.']
#  > Processing time: 0.6204798221588135
#  > Real-time factor: 0.20393483303425108
# Component: 120 - 211
# Duration: 3.0425396825396827

# %%
video_composition = VideoComposition(width=1024, height=1024, fps=fps)
mp4_path = "tts.mp4"
vc = MP4Component(mp4_path=mp4_path, start=1, width=1024, height=1024, fps=fps)
video_composition.add_component(vc)
video_composition.create_video("mp4.mp4")
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'tts.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:00:16.00, start: 0.000000, bitrate: 1877 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1024x1024 [SAR 1:1 DAR 1:1], 2612 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 77 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/var/folders/7k/52l4j6s906q9s88m_c95kdkw0000gn/T/tmp9l081oub.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf60.3.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 22050 Hz, mono, s16, 352 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     690kB time=00:00:15.97 bitrate= 353.9kbits/s speed=2.98e+03x
# video:0kB audio:690kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.011039%
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 video_composition = VideoComposition(width=1024, height=1024, fps=fps)
#       2 mp4_path = "tts.mp4"
# ----> 3 vc = MP4Component(mp4_path=mp4_path, start=1, width=1024, height=1024, fps=fps)
#       4 video_composition.add_component(vc)
#       5 video_composition.create_video("mp4.mp4")
#
# File ~/projects/tiktok/src/video_composition/combo/mp4_componenet.py:8, in MP4Component.__init__(self, mp4_path, start, width, height, fps, *args, **kwargs)
#       6 def __init__(self, mp4_path, start=0, width=1080, height=1920, fps=30,  *args, **kwargs):
#       7     super().__init__(*args, **kwargs)
# ----> 8     ac = AudioFromMP4Component(mp4_path, start=start)
#       9     vc = VideoFromMP4Component(mp4_path, start=start, width=width, height=height, fps=fps)
#      10     self.add_component(vc)
#
# File ~/projects/tiktok/src/video_composition/audio/mp4_audio_component.py:24, in AudioFromMP4Component.__init__(self, mp4_path, sample_rate, *args, **kwargs)
#      13 command = [
#      14     'ffmpeg',
#      15     '-i', mp4_path,           # Input file path
#    (...)
#      20     self.temp_audio_path      # Output temporary file path
#      21 ]
#      22 subprocess.run(command)
# ---> 24 super().__init__(audio_file_path=temp_audio_file, *args, **kwargs)
#
# File ~/projects/tiktok/src/video_composition/audio/audio_file_component.py:13, in AudioFileComponent.__init__(self, audio_file_path, start_time, *args, **kwargs)
#      10     self.audio_data = self.audio_data.mean(axis=1)
#      12 self.duration = len(self.audio_data) / self.sample_rate  # Calculate duration in seconds
# ---> 13 super().__init__(self.audio_data, *args, sample_rate=self.sample_rate, start_time=start_time, **kwargs)
#
# TypeError: AudioComponent.__init__() got an unexpected keyword argument 'start'
