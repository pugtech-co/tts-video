# %%
from src.tts import TextToSpeech
from IPython.display import Audio
import matplotlib.pyplot as plt
# %matplotlib inline

text = "Hello world. This is a test of the text to speech system.  Here's a third sentence. And a fourth. How about a fifth?"
# Out:
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > initialization of speaker-embedding layers.

# %%
# Turn the sentence into an audio object
output = TextToSpeech.text_to_audio(text)
output = TextToSpeech.add_beeps(output)
Audio(output.audio, rate=22050)
# Out:
#  > Text splitted to sentences.
# ['Hello world']
#  > Processing time: 0.39504384994506836
#  > Real-time factor: 0.27207386591981375
#  > Text splitted to sentences.
# ['This is a test of the text to speech system']
#  > Processing time: 0.6824228763580322
#  > Real-time factor: 0.21447298209370882
#  > Text splitted to sentences.
# ["Here's a third sentence"]
#  > Processing time: 0.4697608947753906
#  > Real-time factor: 0.240754642287964
#  > Text splitted to sentences.
# ['And a fourth']
#  > Processing time: 0.288970947265625
#  > Real-time factor: 0.20730769739741772
#  > Text splitted to sentences.
# ['How about a fifth?']
#  > Processing time: 0.3600349426269531
#  > Real-time factor: 0.22299917092484037
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
TextToSpeech.plot_spectrogram_with_words(plt, output)

# %%
output.total_running_time_s
# Out:
# 9.593469387755103
