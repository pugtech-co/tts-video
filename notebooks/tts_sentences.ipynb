# %% [markdown]
# ## This visualizes a multi-sentence TTS with work timestamps

# %%
import sys
sys.path.append('../') # so that we can import packages from parent folder

from src.tts import TextToSpeech
from IPython.display import Audio
import matplotlib.pyplot as plt
# %matplotlib inline

# text = "Hello world. This is a test of the text to speech system.  Here's a third sentence. And a fourth. How about a fifth?"
text = "Then David said to Solomon his son, Be strong and courageous and do it. Do not be afraid and do not be dismayed, for the LORD God, even my God, is with you. He will not leave you or forsake you, until all the work for the service of the house of the LORD is finished."
#4 seconds

# %%
# Turn the sentence into an audio object
output = TextToSpeech.text_to_audio(text, plt=plt)
# output = TextToSpeech.add_beeps(output)
Audio(output.audio, rate=22050)
# Out:
#  > Text splitted to sentences.
# ['Then David said to Solomon his son, Be strong and courageous and do it.']
#  > Processing time: 1.389030933380127
#  > Real-time factor: 0.28346782986294794
#  ----
# sentence: Then David said to Solomon his son, Be strong and courageous and do it.
# split: 14 word indices: 14
# sum split: 14 sum word indices: 14
#  > Text splitted to sentences.
# ['Do not be afraid and do not be dismayed, for the LORD God, even my God, is with you.']
#  > Processing time: 1.317779302597046
#  > Real-time factor: 0.2467143868212952
#  ----
# sentence: Do not be afraid and do not be dismayed, for the LORD God, even my God, is with you.
# split: 18 word indices: 16
# sum split: 32 sum word indices: 30
# split: 18 word indices: 16
#  > Text splitted to sentences.
# ['He will not leave you or forsake you, until all the work for the service of the house of the LORD is finished.']
#  > Processing time: 1.592642068862915
#  > Real-time factor: 0.24938755268170718
#  ----
# sentence: He will not leave you or forsake you, until all the work for the service of the house of the LORD is finished.
# split: 20 word indices: 20
# sum split: 52 sum word indices: 50
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
TextToSpeech.plot_spectrogram_with_words(plt, output)

# %%
output.total_running_time_s
# Out:
# 2.2066213151927436
