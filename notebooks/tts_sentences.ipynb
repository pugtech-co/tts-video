# %% [markdown]
# ## This visualizes a multi-sentence TTS with work timestamps

# %%
import sys
sys.path.append('../') # so that we can import packages from parent folder

from src.tts import TextToSpeech
from IPython.display import Audio
import matplotlib.pyplot as plt
# %matplotlib inline

text = "Hello world. This is a test of the text to speech system.  Here's a third sentence. And a fourth. How about a fifth?"

#4 seconds
# Out:
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > initialization of speaker-embedding layers.

# %%
# Turn the sentence into an audio object
output = TextToSpeech.text_to_audio(text)
output = TextToSpeech.add_beeps(output)
Audio(output.audio, rate=22050)
# Out:
#  > Text splitted to sentences.
# ['Hello world']
#  > Processing time: 0.3809478282928467
#  > Real-time factor: 0.2644804664312742
#  > Text splitted to sentences.
# ['This is a test of the text to speech system']
#  > Processing time: 0.668583869934082
#  > Real-time factor: 0.21644165979631355
#  > Text splitted to sentences.
# ["Here's a third sentence"]
#  > Processing time: 0.43551206588745117
#  > Real-time factor: 0.2083269926418409
#  > Text splitted to sentences.
# ['And a fourth']
#  > Processing time: 0.2849869728088379
#  > Real-time factor: 0.20968909338076866
#  > Text splitted to sentences.
# ['How about a fifth?']
#  > Processing time: 0.3427009582519531
#  > Real-time factor: 0.22017937440138596
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
TextToSpeech.plot_spectrogram_with_words(plt, output)

# %%
output.total_running_time_s
# Out:
# 9.535419501133786
